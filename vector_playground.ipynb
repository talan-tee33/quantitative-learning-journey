# %% [markdown]
# <a href="https://colab.research.google.com/github/talan-tee33/quantitative-learning-journey/blob/main/vector_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from the cloud! This computer isn't saving anything.")
# Out:
# Hello from the cloud! This computer isn't saving anything.
